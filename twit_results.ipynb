# %%
from pprint import pprint
import json

with open('data/export.json', 'r') as handle:
    data = [json.loads(line) for line in handle if line != '\n']
    
pprint(data[0:10])
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Feb 02 20:55:29 +0000 2019',
#   'entities': {'hashtags': [],
#                'symbols': [],
#                'urls': [{'display_url': 'is.gd/YclKJ1',
#                          'expanded_url': 'https://is.gd/YclKJ1',
#                          'indices': [116, 139],
#                          'url': 'https://t.co/GIulik97B3'}],
#                'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 1091802306721439744,
#   'id_str': '1091802306721439744',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'tl',
#   'place': None,
#   'possibly_sensitive': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
# ...

# %%
text = [i['text'] for i in data]
pprint(text[0:10])
# Out:
# ['Sinunog at kinompiska ang P12 milyong halaga ng marijuana sa anim na '
#  'plantasyon sa Agusan del Sur nitong Biyernes.\n'
#  ' https://t.co/GIulik97B3',
#  'RT @rons_post: Cop: ur car smells like marijuana\n'
#  '\n'
#  'Me: whoever smelt it dealt it\n'
#  '\n'
#  'Cop: gosh dangit \n'
#  '\n'
#  'Me: ur under arrest',
#  'RT @browndotflop: Illicitly manufactured fentanyl \n'
#  '\n'
#  'Non-pharmaceutically sourced fentanyl \n'
#  '\n'
#  'This is NOT the same fentanyl that they give yo…',
#  'RT @rons_post: Cop: ur car smells like marijuana\n'
#  '\n'
#  'Me: whoever smelt it dealt it\n'
#  '\n'
#  'Cop: gosh dangit \n'
#  '\n'
#  'Me: ur under arrest',
#  'RT @rons_post: Cop: ur car smells like marijuana\n'
#  '\n'
#  'Me: whoever smelt it dealt it\n'
#  '\n'
#  'Cop: gosh dangit \n'
#  '\n'
#  'Me: ur under arrest',
#  'New Article, check it!\n\nhttps://t.co/fC8aRW0gu2',
#  'RT @rons_post: Cop: ur car smells like marijuana\n'
#  '\n'
#  'Me: whoever smelt it dealt it\n'
# ...
